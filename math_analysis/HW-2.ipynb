# %% [markdown]
# # Домашнее задание

# %% [markdown]
# ## Теория вероятностей

# %% [markdown]
# **Задача 1**. (11 баллов)
#
# В известном магазине техники представлено очень много экземпляров различной бытовой техники двух видов: с возможностью подключения к системе "Умный дом" и без такой возможности. Причем, известно, что эти два вида техники представлены в пропорции 1 : 3 соответственно. Случайным образом выбрали 7 экземпляров техники для розыгрыша среди участниц конкурса "Мисс Рукоделье - 2024".  Какова вероятность, что среди них не более двух экземпляров с возможностью подключения к системе "Умный дом"?
#
# Подробно распишите решение и обоснуйте выбор распределения для моделирования сюжета задачи. Ответ округлите до трёх знаков.

# %% [markdown]
# **Решение:**
# В данной задаче имеются 7 разыгрываемых экземпляров техники с двумя видами функциональности. Соответственно, вероятность возникновения того или иного функционала у экземпляра техники при каждом из семи розыгрышей одинакова. В рамках настоящего задания применимо биноминальное распределение.

# %%
import numpy as np
import scipy as sp

n = 7  # количество испытаний
k = 2  # необходимое количество успехов
p = 0.25  # т.к. экземпляров без функционала "Умного дома" в 3 раза больше

# Для решения применить кумулятивную функцию для биноминального распределения
result = sp.stats.binom.cdf(k, n, p)
print('Ответ:', np.round(result, 3))
# Out:
# Ответ: 0.756

# %% [markdown]
# **Задача 2** (30 баллов)
#
# Дан закон распределения количества публикаций в которой группе телеграм-каналов:

# %% [markdown]
# $$
# \begin{array}{|c|c|c|c|c|c|c|}
# \hline X \text { (число публикаций) } & 0 & 1 & 2 & 3 & 4 & 5 \\
# \hline \mathrm{P} \text { (вероятность) } & ? & 0,3 & 0,3 & 0,2 & 0,1 & 0,1 \\
# \hline
# \end{array}
# $$

# %% [markdown]
# Найдите пропущенную вероятность для X = 0, математическое ожидание и дисперсию. Решите задачу "вручную" и с помощью python.

# %% [markdown]
# **Решение:**
# Как известно, сумма вероятностей для событий, которые заключают в себе все возможные исходы, равна 1. Вычислим недостающую вероятность:
#
# $$P_0 = 1 - 0.3 - 0.3 - 0.2 - 0.1 - 0.1 = 0$$
#
# Математическое ожидание вычисляется по следующей формуле:
#
# $$ E(x) = \mu_x = \sum x_i \cdot P(x = x_i) $$
# где $i$ - индекс переменной;
# $x_i$ - значение случайной величины с индексом $i$;
# $P(x=x_i)$ - вероятность того, что случайная величина принимает значение $x_i$.
#
# По вышеуказанной формуле найдем математическое ожидание в рамках данной задачи:
#
# $$E(x) = 0*0.0 + 1*0.3 + 2*0.3 + 3*0.2 + 4*0.1 + 5*0.1 = 2.4$$
#
# Дисперсия вычисляется по следующей формуле:
#
# $$D(x)=\sigma_{x}^{2}=E\left(x^{2}\right)-(E(x))^{2}$$
#
# Получим дисперсию:
#
# $$ E(x^2) = 0^2*0.0 + 1^2*0.3 + 2^2*0.3 + 3^2*0.2 + 4^2*0.1 + 5^2*0.1 = 0 + 0.3 + 1.2 + 1.8 + 1.6 + 2.5 = 7.4 $$
# $$ D(x) = 7.4 - 2.4^2 = 7.4 - 5.76 = 1.64 $$
#
# **Ответ:**  $E(x) = 2.4$, $D(x) = 1.64$.

# %%
# Решение на Python
# Инициализировать исходные данные
x = np.array([0, 1, 2, 3, 4, 5])
p = np.array([0.0, 0.3, 0.3, 0.2, 0.1, 0.1])

# Получить матожидание
E_x = np.sum(x * p)

# Получить дисперсию
D_x = np.sum((x ** 2) * p) - E_x ** 2

print('Математическое ожидание (E(x)):', E_x)
print('Дисперсия (D(x)):', np.round(D_x, 2))
# Out:
# Математическое ожидание (E(x)): 2.4
# Дисперсия (D(x)): 1.64

# %% [markdown]
# **Задача 3** (25 баллов)

# %% [markdown]
# Компания приобрела 10 000 новых ноутбуков. Вероятность поломки одного ноутбука в течение месяца равна 0,0002. Предполагается, что поломки отдельных ноутбуков происходят независимо друг от друга.
#
# **Вопрос 1**. Найдите вероятность того, что за месяц сломается ровно 1 ноутбук.
# Решение объясните. (5 баллов)

# %% [markdown]
# **Решение:**
# По аналогии с задачей 1 имеем количество испытаний и два возможных исхода, соответственно, вновь используем биноминальное распределение.

# %%
n = 10000  # количество испытаний
k = 1  # необходимое количество успехов
p = 0.0002 # т.к. экземпляров без функционала "Умного дома" в 3 раза больше

# Найти вероятность успеха в одном испытании
result = sp.stats.binom.pmf(k, n, p)
print('Ответ:', np.round(result, 3))
# Out:
# Ответ: 0.271

# %% [markdown]
# **Вопрос 2**. Компания планирует ввести программу расширенной гарантии, по которой она будет бесплатно ремонтировать или заменять ноутбуки, сломавшиеся в течение месяца. Если общее количество поломок за месяц превысит 5 ноутбуков, компания понесет значительные дополнительные расходы.
#
# а) Найдите вероятность того, что за месяц сломается более 5 ноутбуков. Решение объясните (10 баллов)

# %%
k = 5  # необходимое количество поломок

# Для решения используем функцию выживаемости
result = sp.stats.binom.sf(k, n, p)
print('Ответ:', np.round(result, 3))
# Out:
# Ответ: 0.017

# %% [markdown]
# б) Если стоимость ремонта или замены одного ноутбука составляет 500 долларов, вычислите математическое ожидание общих расходов компании на поломки за один месяц. (10 баллов)

# %%
cost = 500  # стоимость ремонта

# Для нахождения общего математического ожидания необходимо умножить матожидание поломки на стоимость ремонта
result = sp.stats.binom.stats(n, p, moments='m') * cost
print('Ответ:', np.round(result, 3))
# Out:
# Ответ: 1000.0
